// %%
%%file ../out/main.cpp
#include <iostream>
#include <SDL.h>
#include <GL/glew.h>

int main(int argc, char **argv) {
    SDL_Init(SDL_INIT_EVERYTHING);

    std::cout << "Hello World!";
    return 0;
}
// Out:
// Overwriting ../out/main.cpp

// %%
!cd ../out && make
// Out:
// make out && ./out
// make[1]: Entering directory '/home/galaxy/code/jupyter/notebook/cpp/sdl/out'
// g++ main.cpp -o out `sdl2-config --cflags --libs` -lGLEW -lGL -lglut
// make[1]: Leaving directory '/home/galaxy/code/jupyter/notebook/cpp/sdl/out'
// Hello World!

// %%
!vscode
