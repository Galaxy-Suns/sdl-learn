// %%
!cd ../code && ./ln_before.sh 8_IOManager

// %% [markdown]
// ## IOManager
//
// * 创建 `IOManager` 类
// * 创建文件读取方法

// %%
%%file ../code/8_IOManager/IOManager.h
#pragma once
#include <vector>
#include <string>
    
class IOManager
{
public:
    // 读取文件到字符串buffer 并自动适应文件大小
    static bool readFileToBuffer(std::stirng filePath, std::vector<unsigned char> &buffer);
};
// Out:
// Writing ../code/8_IOManager/IOManager.h

// %%
%%file ../code/8_IOManager/IOManager.cpp
#include "IOManager.h"
#include <fstream>

// 读取文件到字符串buffer 并自动适应文件大小
bool IOManager::readFileToBuffer(std::stirng filePath, std::vector<char> &buffer) {
    std::ifstream file(filePath, std::ios::binary);
    if (file.fail()) {
        perror(filePath.c_str());
        return false
    }
    
    // seek to the end
    file.seekg(0, std::ios::end);
    // get the file size (byte)
    int fileSize = file.tellG();
    file.seekg(0, std::ios::beg);

    fileSize -= file.tellg(); // 不考虑元信息大小

    buffer.resize(fileSize);
    file.read((char *)&(buffer[0]), fileSize);
    file.close();
    
    return true;
}
// Out:
// Writing ../code/8_IOManager/IOManager.cpp
